# %% [markdown]
# <a href="https://colab.research.google.com/github/sardarnick/dataanalysiscolab/blob/main/data_analysis_2702.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Business_Management_Dataset.csv')
df.head(4)
plt.scatter(df['Employee_Satisfaction'], df['Employee_Turnover'])
plt.xlabel('Employee Satisfaction')
plt.ylabel('Employee Turnover')
plt.title('Employee Satisfaction vs Employee Turnover')
plt.show()

# %%
print(df.describe())
# Out:
#        Employee_Satisfaction  Employee_Turnover  Training_Hours  Productivity  \
# count           20000.000000       20000.000000    20000.000000  20000.000000
# mean                5.520498          14.976989       39.876790     79.976994
# std                 2.603473           8.675058       15.004479     20.004375
# min                 1.000000           0.000000      -16.190000      2.680000
# 25%                 3.250000           7.480000       29.710000     66.310000
# 50%                 5.530000          15.040000       39.995000     80.000000
# 75%                 7.760000          22.500000       50.070000     93.490000
# max                10.000000          30.000000      101.140000    171.690000
#
#        Annual_Sales  Market_Share
# count  2.000000e+04  20000.000000
# mean   5.001757e+05     24.905011
# std    1.979201e+05     14.497829
# min   -2.360634e+05      0.000000
# 25%    3.670262e+05     12.360000
# 50%    4.995463e+05     24.945000
# ...
